# %%
import requests
import string
import re
import urllib

# %%
url = "https://etenders.gov.in/eprocure/app"

# %%
response = requests.get(url, headers={"user-Agent": "XY"})

# %%
response.status_code
# Out:
# 200

# %%
page_contents = response.text

# %%
page_contents
# Out:
# '<head>\r\n\t<base target="_self">\r\n\t<title>Government eProcurement System</title>\r\n</head>\r\n<!-- BEGIN: HEADER -->\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<!-- Application: null -->\n<!-- Page: Home -->\n<!-- Generated: Wed Feb 15 17:34:25 IST 2023 -->\n<html>\n<head>\n<meta name="generator" content="Tapestry Application Framework, version 4.1.6-SNAPSHOT" />\n<meta http-equiv="Content-Type" content="text/html;charset=UTF-8" />\n<title>eProcurement System</title>\n<script type="text/javascript">djConfig = {"baseRelativePath":"/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2F","preventBackButtonFix":false,"parseWidgets":false,"locale":"en-us"} </script>\n\n<script type="text/javascript" src="/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2Fdojo.js"></script><script type="text/javascript" src="/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2Fdojo2.js"></script>\n<script type
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page_contents, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <head>
#  <base target="_self"/>
#  <title>
#   Government eProcurement System
#  </title>
# </head>
# <!-- BEGIN: HEADER -->
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <!-- Application: null -->
# <!-- Page: Home -->
# <!-- Generated: Wed Feb 15 17:34:25 IST 2023 -->
# <html>
#  <head>
#   <meta content="Tapestry Application Framework, version 4.1.6-SNAPSHOT" name="generator"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    eProcurement System
#   </title>
#   <script type="text/javascript">
#    djConfig = {"baseRelativePath":"/eprocure/app?service=asset&path=%2Fdojo-0.4.3-custom-4.1.6%2F","preventBackButtonFix":false,"parseWidgets":false,"locale":"en-us"}
#   </script>
#   <script src="/eprocure/app?service=asset&amp;path=%2Fdojo-0.4.3-custom-4.1.6%2Fdojo.js" type="text/javascript">
#   </script>
# ...

# %%
title = soup.find('title')
title = title.text.replace('\n'," ")
title
# Out:
# 'Government eProcurement System'

# %%
content=soup.findAll(attrs={'class':'page_desc'})
content=content[0].text.replace('\n'," ")
content
# Out:
# 'The eProcurement System enables the Tenderers to download the Tender Schedule free of cost and then submit the bids online through this portal.'

# %%
for link in soup.find_all('a', attrs={'href': re.compile("^https")}):
    print(link)
type(link)
# Out:
# <a class="link1" href="https://gepnicreports.gov.in/eprocreports/etenders/" id="GenericLink" target="_blank" title="MIS Reports">MIS Reports</a>
# <a href="https://gepnic.gov.in" id="GenericLink_0" target="_blank" title="link"><img border="0" height="34" id="Any_1" src="images/Gepnic Logo.png" width="160"/></a>
# <a href="https://gem.gov.in" id="GenericLink_0_1" target="_blank" title="Government e-Marketing of India - External link that opens in a new window"><img border="0" height="34" id="Any_3" src="images/gem.png" width="160"/></a>
# <a href="https://eprocure.gov.in/eprocdashboard/" id="hleproc_dash" target="_blank" title="CPPP Dashboard">
# <img alt="app-dashboard" border="0" id="eproc_dash" src="images/app-dashboard.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=gov.nic.eproc&amp;hl=en" id="hleproc_playstore" target="_blank" title="Mobile App">
# <img alt="playstore" border="0" id="eproc_playstore" src="images/playstore.png"/>
# </a>
# ...

# %%
links= soup.find_all('a', {'class': 'link1'})

# %%
links
# Out:
# [<a class="link1" href="https://gepnicreports.gov.in/eprocreports/etenders/" id="GenericLink" target="_blank" title="MIS Reports">MIS Reports</a>,
#  <a class="link1" href="/eprocure/app?page=FrontEndTendersByLocation&amp;service=page" id="PageLink_0" target="_self" title="Tenders by Location">Tenders by Location</a>,
#  <a class="link1" href="/eprocure/app?page=FrontEndTendersByOrganisation&amp;service=page" id="PageLink_1" target="_self" title="Tenders by Organisation">Tenders by Organisation</a>,
#  <a class="link1" href="/eprocure/app?page=FrontEndTendersByClassification&amp;service=page" id="PageLink_2" target="_self" title="Tenders by Classification">Tenders by Classification</a>,
#  <a class="link1" href="/eprocure/app?page=FrontEndTendersInArchive&amp;service=page" id="PageLink_3" target="_self" title="Tenders in Archive">Tenders in Archive</a>,
# ...

# %%
sublinks = soup.find_all('a', {'class': 'Menu'})

# %%
sublinks
# Out:
# [<a class="Menu" href="/eprocure/app?page=WebScreenReaderAccess&amp;service=page" id="link1" name="link1">Screen Reader Access</a>,
#  <a class="Menu" href="/eprocure/app?page=FrontEndAdvancedSearch&amp;service=page" id="link1" name="link1" target="_self" title="Search">Search</a>,
#  <a class="Menu" href="/eprocure/app?page=FrontEndLatestActiveTenders&amp;service=page" id="link1" name="link1" target="_self" title="Active Tenders">Active Tenders</a>,
#  <a class="Menu" href="/eprocure/app?page=FrontEndListTendersbyDate&amp;service=page" id="link1" name="link1" target="_self" title="Tenders by Closing Date">Tenders by Closing Date</a>,
#  <a class="Menu" href="/eprocure/app?page=FrontEndLatestActiveCorrigendums&amp;service=page" id="link1" name="link1" target="_self" title="Corrigendum">Corrigendum</a>,
#  <a class="Menu" href="/eprocure/app?page=ResultOfTenders&amp;service=page" id="link1" name="link1" target="_self" title="Results of Tenders">Results of Tenders</a>]

# %%
subsublinks = soup.find_all('a', {'class': 'notice_link'})

# %%
subsublinks
# Out:
# [<a class="notice_link" href="/eprocure/app?page=WebAnnouncements&amp;service=page#109" id="PageLink">« Configuration required for Edge Browser</a>]

# %%
links4 = soup.find_all('a', {'class': 'Clickhere'})
links4
# Out:
# [<a class="Clickhere" href="/eprocure/app?page=FrontEndLatestActiveTenders&amp;service=page" id="PageLink_14" title="More Tenders">More...</a>,
#  <a class="Clickhere" href="/eprocure/app?page=FrontEndLatestActiveCorrigendums&amp;service=page" id="PageLink_15" title="More Corrigendums">More...</a>,
#  <a class="Clickhere" href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T" id="DirectLink_20" style="display:none">   Online Bidder Enrollment</a>,
#  <a class="Clickhere" href="/eprocure/app?component=%24WebHomeBorder.%24WebRightMenu.%24DirectLink_0&amp;page=Home&amp;service=direct&amp;session=T" id="DirectLink_21" onclick="return openPopUp(this, 'location=no, scrollbars=yes, toolbar=no, width=1004, height=750, directories=no, menubar=no, resizable=yes, status=no, titlebar=yes');" style="display:none" title="Generate / Forgot Password">  Generate / Forgot Password?</a>,
# ...

# %%
tablelinks = soup.find_all('a', {'class': 'link2'})
tablelinks
# Out:
# [<a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SAthDUMjE4sD%2BqDZDUzvaRQ%3D%3D" id="DirectLink">1. Spares</a>,
#  <a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=S%2FWD%2BzSqL0UmgXHXEpQBbMA%3D%3D" id="DirectLink_0">2. 14-VIII/SGA(612-OTE)20PB/T-117</a>,
#  <a class="link2" href="/eprocure/app?component=%24DirectLink&amp;page=Home&amp;service=direct&amp;session=T&amp;sp=SHhioLboKgDEArUoVGUigeQ%3D%3D" id="DirectLink_1">3. IE services for Construction of 4-lane AC New GF Highway Section Mancherial-Warangal from Pangidipalle village at Ch.72.350 Km-Oorugonda village at Ch.112.240 Km Length 39.890 km under EC NH-O as part of Nagpur-Vijayawada on HAM in Telangana PKG-III</a>,
# ...

# %%
Image = soup.find_all('img')

# %%
print(Image)
# Out:
# [<img alt="Logo" border="0" height="83" id="Any_0" src="images/topban.png" usemap="#Map" width="1005"/>, <img alt="Home" border="0" height="18" name="Image4" src="images/homea.png" width="47"/>, <img alt="Contact Us" border="0" height="18" name="Image5" src="images/contacta.png" width="78"/>, <img alt="Sitemap" border="0" height="18" name="Image6" src="images/sitemapa.png" width="63"/>, <img alt="Notices" height="16" src="images/notice.png" width="15"> </img>, <img border="0" height="34" id="Any_1" src="images/Gepnic Logo.png" width="160"/>, <img border="0" height="34" id="Any_2" src="images/indiagovin.png" width="160"/>, <img border="0" height="34" id="Any_3" src="images/gem.png" width="160"/>, <img border="0" height="34" id="Any_4" src="images/cppp-img.png" width="160"/>, <img alt="app-dashboard" border="0" id="eproc_dash" src="images/app-dashboard.png"/>, <img alt="playstore" border="0" id="eproc_playstore" src="images/playstore.png"/>, <img alt="playstore" border="0" id="eproc_pl
# ...

# %%
text = soup.findAll(attrs={'class':'text2'})
text = text[0].text.replace('\n'," ")
text
# Out:
# 'Visitor No:3791839'

# %%
import csv

# %%
with open("Taiyo.csv", "w") as csv_file:
    csv_write = csv.writer(csv_file)
    csv_write.writerow(page_contents)
